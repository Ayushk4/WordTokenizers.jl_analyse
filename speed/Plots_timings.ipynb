# %%
using Plots

# %%
x_label = ["WordTokenizers.jl\n NLTK Tokenize",
           "WordTokenizers.jl \n TweetTokenize",
           "WordTokenizers.jl \n TokTok",
           "Spacy",
           "NLTK - Word Tokenizer"]

vals = [6.223, 5.286, 24.109, 21.979, 34.053] # Mean vals from benchmarking on each

bar(ylabel= "Time in seconds", x_label, vals, title = "Speed Comparison of Tokenizers", leg=false, fillcolor=[:green, :green, :green, :red, :purple], xtickfont=font(7))
