# %%
using Plots

# %%
x_label = ["WordTokenizers.jl - toktok" "Spacy" "NLTK - Word Tokenizer" "WordTokenizers.jl -\n tweet tokenizer"]
vals = [6.488322 24.139985 32.180763 24.634809]
libs = ["WordTokenizers.jl" "Spacy" "NLTK" "WordTokenizers.jl"]

bar(ylabel= "Time in seconds for IMDB Datadet", x_label, vals, title = "Tokenizers Speed", leg=false)
